# %%
import os, sys
import dotenv

import pandas as pd
import numpy as np

dotenv.load_dotenv('../.env')    
PATH_DATA = os.environ.get('PATH_OPENSKY') + os.environ.get('PATH_REL_DATA')
PATH_DATA
# Out:
# '/home/ties/Documents/00_Uni/24W/Foundations/opensky/data/'

# %%
feed_files = os.listdir(PATH_DATA + 'feed_posts')
feed_file = feed_files[0]
path_feed_file = PATH_DATA + 'feed_posts/' + feed_file  
feed_files, path_feed_file
# Out:
# (['Science.jsonl.gz',
#   'Political Science.jsonl.gz',
#   'BookSky.jsonl.gz',
#   'Blacksky.jsonl.gz',
#   'Game Dev.jsonl.gz',
#   'AcademicSky.jsonl.gz',
#   '#Disability.jsonl.gz',
#   'News.jsonl.gz',
#   "What's History.jsonl.gz",
#   'GreenSky.jsonl.gz',
#   '#UkrainianView.jsonl.gz'],
#  '/home/ties/Documents/00_Uni/24W/Foundations/opensky/data/feed_posts/Science.jsonl.gz')

# %%
import gzip
import json

def load_jsonl(input_path) -> list:
    """
    Read list of objects from a JSON lines file.
    """
    count = 0
    data = []
    with gzip.open(input_path, 'r') as f:
        for line in f:
            line = f.readline().decode('utf-8').rstrip()
            data.append(json.loads(line))
            count += 1

    print(f'Loaded {count} lines from {input_path}') 
    return data 

    #cols = ['post_id', 'user_id', 'instance', 'date', 'text', 'langs', 'repost_count', 'reply_to', 'replied_author', 'thread_root', 'thread_root_author', 'quotes', 'quoted_author', 'labels']
    #return pd.DataFrame(lines, columns=cols)

load_jsonl(path_feed_file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[65], line 19
#      14     return data
#      16     #cols = ['post_id', 'user_id', 'instance', 'date', 'text', 'langs', 'repost_count', 'reply_to', 'replied_author', 'thread_root', 'thread_root_author', 'quotes', 'quoted_author', 'labels']
#      17     #return pd.DataFrame(lines, columns=cols)
# ---> 19 load_jsonl(path_feed_file)
#
# Cell In[65], line 12, in load_jsonl(input_path)
#      10     for line in f:
#      11         line = f.readline().decode('utf-8').rstrip()
# ---> 12         data.append(json.loads(line))
#      14 return data
#
# File /usr/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
# ...

# %%
data = []
with gzip.open(path_feed_file, 'r') as f:
    for line in range(10000):
        line = f.readline().decode('utf-8').rstrip()
        data.append(json.loads(line))
pd.DataFrame(data)
# Out:
#         post_id  user_id     instance          date  \
# 0        134430    10507  bsky.social  202402101508
# 1        134430    10507  bsky.social  202402101508
# 2      68828985    83711  bsky.social  202403182331
# 3     182457117  1152097  bsky.social  202403182314
# 4      12805677   165925  bsky.social  202403182314
# ...         ...      ...          ...           ...
# 9995    3465670    35868  bsky.social  202312251623
# 9996  204913169    65551  bsky.social  202312251622
# 9997  107174148   331091  bsky.social  202312251613
# 9998    6190385      134  bsky.social  202312251529
# 9999   83876298   103530  bsky.social  202312251400
#
#                                                    text  langs  like_count  \
# 0     Welcome to the Science feed!\n\nPlease read ou...  [eng]         497
# 1     Welcome to the Science feed!\n\nPlease read ou...  [eng]         497
# 2     VERY proud of my Esri colleague Kevin Butler f...  [eng]          14
# ...

# %%
with 
df = pd.read_json(PATH_DATA + '/feeds_posts/Blacksky.jsonl.gz', lines=True, compression='gzip')
df
# Out:
# /tmp/ipykernel_216535/2186299374.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(PATH_DATA + '/feeds_posts/Blacksky.jsonl.gz', lines=True, compression='gzip')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_json(PATH_DATA + '/feeds_posts/Blacksky.jsonl.gz', lines=True, compression='gzip')
#       2 df
#
# File ~/Documents/00_Uni/24W/Foundations/opensky/.venv/lib/python3.10/site-packages/pandas/io/json/_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# ...

# %%
df.isna().sum()
# Out:
# instance               2426
# langs                 12909
# min_date               2426
# max_date               2426
# mean_sent_score      338029
# mean_like_count        2426
# mean_reply_count       2426
# mean_repost_count      2426
# n_posts                2426
# caught_exception          0
# dtype: int64

# %%
df.langs = df.langs.str.split(',')
df
# Out:
#             instance                 langs                 min_date  \
# 288811   bsky.social                 [jpn]  1976-05-31 14:49:40.250
# 527934   bsky.social  [eng, heb, jpn, fra]  1976-05-30 12:23:51.918
# 1632691  bsky.social                 [spa]  1976-05-30 13:16:31.226
# 1909409  bsky.social                 [jpn]  1976-05-31 14:48:11.431
# 2902501  bsky.social                 [kor]  1976-05-30 12:59:01.311
# ...              ...                   ...                      ...
# 495380   bsky.social                 [eng]  1976-05-30 12:40:30.146
# 502241   bsky.social                 [eng]  1976-05-31 14:47:42.021
# 1652601  bsky.social  [spa, eng, cat, jpn]  1976-05-30 12:09:11.814
# 1838341  bsky.social                 [por]  1976-05-30 12:23:50.927
# 3401925          esq                 [eng]  1976-05-30 13:47:41.035
#
#                         max_date  mean_sent_score  mean_like_count  \
# 288811   1976-05-31 15:06:01.140              NaN         4.636364
# ...

# %%
df.langs.explode().value_counts().head(20)
# Out:
# langs
# eng    390937
# jpn    277884
# deu     68447
# spa     55683
# fra     51556
# por     34400
# kor     28512
# zho     25951
# rus     22243
# nld     17063
# ita     14246
# swe     10952
# fin     10153
# ukr     10057
# ell      8265
# tha      7986
# pol      7265
# tur      7265
# ara      5939
# vie      5913
# Name: count, dtype: int64
