# %%
import os, sys
import dotenv

import pandas as pd
import numpy as np

dotenv.load_dotenv('../.env')    
PATH_DATA = os.environ.get('PATH_OPENSKY') + os.environ.get('PATH_REL_DATA')
PATH_DATA
# Out:
# '/home/ties/Documents/00_Uni/24W/Foundations/opensky/data/'

# %%
feed_files = os.listdir(PATH_DATA + 'feed_posts')
feed_file = feed_files[0]
path_feed_file = PATH_DATA + 'feed_posts/' + feed_file  
feed_files, path_feed_file
# Out:
# (['Science.jsonl.gz',
#   'Political Science.jsonl.gz',
#   'BookSky.jsonl.gz',
#   'Blacksky.jsonl.gz',
#   'Game Dev.jsonl.gz',
#   'AcademicSky.jsonl.gz',
#   '#Disability.jsonl.gz',
#   'News.jsonl.gz',
#   "What's History.jsonl.gz",
#   'GreenSky.jsonl.gz',
#   '#UkrainianView.jsonl.gz'],
#  '/home/ties/Documents/00_Uni/24W/Foundations/opensky/data/feed_posts/Science.jsonl.gz')

# %%
import gzip
import json

def load_jsonl(input_path) -> list:
    """
    Read list of objects from a JSON lines file.
    """
    data = []
    with gzip.open(input_path, 'r') as f:
        for line in f:
            try:
                line = f.readline()
                line = line.decode('utf-8')
                line = line.rstrip()
                data.append(json.loads(line))
            except json.JSONDecodeError as e:
                print(f'Error in line: {line}')
                print(e)

    print(f'Loaded {len(data)} lines from {input_path}') 

    cols = ['post_id', 'user_id', 'instance', 'date', 'text', 'langs', 'repost_count', 'reply_to', 'replied_author', 'thread_root', 'thread_root_author', 'quotes', 'quoted_author', 'labels']
    return pd.DataFrame(data)

df = load_jsonl(path_feed_file)
df
# Out:
# Error in line:
# Expecting value: line 1 column 1 (char 0)
# Loaded 16915 lines from /home/ties/Documents/00_Uni/24W/Foundations/opensky/data/feed_posts/Science.jsonl.gz
#          post_id  user_id     instance          date  \
# 0         134430    10507  bsky.social  202402101508
# 1      182457117  1152097  bsky.social  202403182314
# 2       17759651      558  bsky.social  202403182310
# 3       77009156    35868  bsky.social  202403182240
# 4       27536774   286675  bsky.social  202403182205
# ...          ...      ...          ...           ...
# 16910   61538753    27153       social  202306040311
# 16911     165392    27153       social  202306022238
# 16912   71957455   814481  bsky.social  202306020625
# 16913   71957467   814481  bsky.social  202306020604
# 16914   26319660     6547  bsky.social  202306010643
#
#                                                     text  langs  like_count  \
# 0      Welcome to the Science feed!\n\nPlease read ou...  [eng]         497
# 1      AI was revolutionized by an old idea (neural n...  [eng]           5
# 2                                                    🦑🧪🌎  [eng]          25
# 3                                                      🧪  [eng]           2
# 4                                  Forgot 🧪 ... oh well!  [eng]           4
# ...                                                  ...    ...         ...
# 16910  Done done done\n\nFor those tagged in - if you...   None          19
# 16911  I have built a custom feed at https://bsky.app...   None          65
# 16912  This reduction in biological maintenance is ev...   None           0
# 16913  One of the striking aspects of isomyosmine is ...   None           0
# 16914                                🧬🔬⚗️🔭🥼🧪👩🏻‍🔬 SCIENCE   None           1
#
#        reply_count  repost_count    reply_to  replied_author  thread_root  \
# 0               29            62         NaN             NaN          NaN
# 1                2             0         NaN             NaN          NaN
# 2                0            10         NaN             NaN          NaN
# 3                0             1         NaN             NaN          NaN
# 4                0             0         NaN             NaN          NaN
# ...            ...           ...         ...             ...          ...
# 16910            2            10  14060175.0        448984.0     165392.0
# 16911           22            20         NaN             NaN          NaN
# 16912            1             0  71957456.0        814481.0   71957428.0
# 16913            1             0  71957468.0        814481.0   71957428.0
# 16914            0             0  26082396.0         10507.0   26082396.0
#
#        thread_root_author      quotes  quoted_author labels
# 0                     NaN         NaN            NaN   None
# 1                     NaN         NaN            NaN   None
# 2                     NaN  17759652.0       172930.0   None
# 3                     NaN   1431706.0       385833.0   None
# 4                     NaN  27536775.0       286675.0   None
# ...                   ...         ...            ...    ...
# 16910             27153.0         NaN            NaN   None
# 16911                 NaN         NaN            NaN   None
# 16912            814481.0         NaN            NaN   None
# 16913            814481.0         NaN            NaN   None
# 16914             10507.0         NaN            NaN   None
#
# [16915 rows x 16 columns]

# %%
df.isna().sum()
# Out:
# post_id                   0
# user_id                   0
# instance                  0
# date                      0
# text                      0
# langs                  1042
# like_count                0
# reply_count               0
# repost_count              0
# reply_to              14711
# replied_author        14711
# thread_root           14711
# thread_root_author    14711
# quotes                14378
# quoted_author         14378
# labels                16914
# dtype: int64

# %%
feed_files = os.listdir(PATH_DATA + 'feed_posts_likes')
path_feed_likes_files = PATH_DATA + 'feed_posts/' + feed_file[0]
